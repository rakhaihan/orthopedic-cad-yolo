# %%
from pathlib import Path
import yaml

yaml_path = Path("D:/Education/University/telkom/mulai kuliah/SMT 6/Tatulim/project/cad-ortopedi/data/yolo_dataset.yaml")

cfg = yaml.safe_load(open(yaml_path))
base = yaml_path.parent if yaml_path.exists() else Path(".")

img_dir = (base / cfg['path']).resolve()
train = (base / cfg['train']).resolve()
val = (base / cfg['val']).resolve()
test = (base / cfg['test']).resolve()

print("images dir:", img_dir, "exists:", img_dir.exists())
print("train file:", train, "exists:", train.exists())
print("val file:", val, "exists:", val.exists())
print("test file:", test, "exists:", test.exists())
# Out:
# images dir: D:\Education\University\telkom\mulai kuliah\SMT 6\Tatulim\project\cad-ortopedi\data\processed\images_640 exists: True
# train file: D:\Education\University\telkom\mulai kuliah\SMT 6\Tatulim\project\cad-ortopedi\data\splits\train.txt exists: True
# val file: D:\Education\University\telkom\mulai kuliah\SMT 6\Tatulim\project\cad-ortopedi\data\splits\val.txt exists: True
# test file: D:\Education\University\telkom\mulai kuliah\SMT 6\Tatulim\project\cad-ortopedi\data\splits\test.txt exists: True
